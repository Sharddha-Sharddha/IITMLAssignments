# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharddha-Sharddha/IITMLAssignments/blob/main/Stats%26prob_Casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Dataset Link: https://drive.google.com/file/d/1RYDIAYsstlSIZc88a7Dli0yFzjLAI2uI/view?usp=sharing

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/country_profile_variables.csv')
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
df.head(10)
# Out:
#                country          Region Surface area (km2)  \
# 0          Afghanistan    SouthernAsia             652864
# 1              Albania  SouthernEurope              28748
# 2              Algeria  NorthernAfrica            2381741
# 3       American Samoa       Polynesia                199
# 4              Andorra  SouthernEurope                468
# 5               Angola    MiddleAfrica            1246700
# 6             Anguilla       Caribbean                 91
# 7  Antigua and Barbuda       Caribbean                442
# 8            Argentina    SouthAmerica            2780400
# 9              Armenia     WesternAsia              29743
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# ...

# %%
df.tail(10)
# Out:
#                                 country             Region Surface area (km2)  \
# 219                             Uruguay       SouthAmerica             173626
# 220                          Uzbekistan        CentralAsia             448969
# 221                             Vanuatu          Melanesia              12189
# 222  Venezuela (Bolivarian Republic of)       SouthAmerica             912050
# 223                            Viet Nam  South-easternAsia             330967
# 224           Wallis and Futuna Islands          Polynesia                142
# 225                      Western Sahara     NorthernAfrica             266000
# 226                               Yemen        WesternAsia             527968
# 227                              Zambia      EasternAfrica             752612
# 228                            Zimbabwe      EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
#Taking a sample out of the population

sample_df=df.sample(30, random_state=34)
sample_df
# Out:
#                                    country             Region  \
# 104                                  Japan        EasternAsia
# 154                                  Palau         Micronesia
# 55   Democratic People's Republic of Korea        EasternAsia
# 93                                 Hungary      EasternEurope
# 125                                  Malta     SouthernEurope
# 30                       Brunei Darussalam  South-easternAsia
# 211                                 Tuvalu          Polynesia
# 190                                  Spain     SouthernEurope
# 200                               Thailand  South-easternAsia
# 14                                 Bahamas          Caribbean
# 97              Iran (Islamic Republic of)       SouthernAsia
# 26                  Bosnia and Herzegovina     SouthernEurope
# 10                                   Aruba          Caribbean
# 53                                  Cyprus        WesternAsia
# ...

# %%
df['Population in thousands (2017)']
# Out:
# 0      35530
# 1       2930
# 2      41318
# 3         56
# 4         77
#        ...
# 224       12
# 225      553
# 226    28250
# 227    17094
# 228    16530
# Name: Population in thousands (2017), Length: 229, dtype: int64

# %% [markdown]
# #Central Tendencies

# %%
#mean=> sum/length

sumCol=sum(df['Population in thousands (2017)'])
length=len(df['Population in thousands (2017)'])

print(sumCol/length)
# Out:
# 32756.794759825327

# %%
df['Population in thousands (2017)'].mean()
# Out:
# np.float64(32756.794759825327)

# %%
#median=>
#1. sort the values
#2. fetch the mid index
#3. get the data using index fetched in previous step

df['Population in thousands (2017)'].median()
# Out:
# 5448.0

# %%
#mode=> most frequent value

df['Region'].mode()
# Out:
# 0    Caribbean
# Name: Region, dtype: object

# %% [markdown]
# #Measures of Variation

# %%
#Range

min_val=df['Population in thousands (2017)'].min()
print("Min: ",min_val)

max_val=df['Population in thousands (2017)'].max()
print("Max: ",max_val)

r=max_val-min_val
print("Range: ",r)
# Out:
# Min:  1
# Max:  1409517
# Range:  1409516

# %%
Q1=df['Population in thousands (2017)'].quantile(0.25)
print(Q1)

Q2=df['Population in thousands (2017)'].quantile(0.50)
print(Q2)

Q3=df['Population in thousands (2017)'].quantile(0.75)
print(Q3)
# Out:
# 431.0
# 5448.0
# 19193.0

# %%
sns.boxplot(df['Population in thousands (2017)'])
plt.title('Population in thousands (2017)')
plt.show()

# %%
Q1=df['Population in thousands (2017)'].quantile(0.25)
Q3=df['Population in thousands (2017)'].quantile(0.75)

IQR=Q3-Q1

LB=Q1-1.5*(IQR)
UB=Q3+1.5*(IQR)

print(LB,UB)
df=df[(df['Population in thousands (2017)']>=LB)&(df['Population in thousands (2017)']<=UB)]
# Out:
# -27712.0 47336.0

# %%
df.shape
# Out:
# (200, 50)

# %%
229-200
# Out:
# 29

# %%
df[(df['Population in thousands (2017)']<LB)]
# Out:
# Empty DataFrame
# ...

# %%
df[(df['Population in thousands (2017)']>UB)]
# Out:
# Empty DataFrame
# ...

# %%
df['Population in thousands (2017)'].std()
# Out:
# 11279.78925484731

# %% [markdown]
# #Label Encoding
# - Converting the object(string) type of data into numerical data so that
# the machines can understand it better and work with it

# %%
df['Region']
# Out:
# 0        SouthernAsia
# 1      SouthernEurope
# 2      NorthernAfrica
# 3           Polynesia
# 4      SouthernEurope
#             ...
# 224         Polynesia
# 225    NorthernAfrica
# 226       WesternAsia
# 227     EasternAfrica
# 228     EasternAfrica
# Name: Region, Length: 200, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df['Region']=LE.fit_transform(df['Region'])
#.fit(): learn the unique categories and assign a unique integer to each
#.transform(): apply the encoding to your original data using the fitted mapping
# Out:
# /tmp/ipython-input-68-1682125662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region']=LE.fit_transform(df['Region'])

# %%
print("Mapping (classes):", LE.classes_)
# Out:
# Mapping (classes): ['Caribbean' 'CentralAmerica' 'CentralAsia' 'EasternAfrica' 'EasternAsia'
#  'EasternEurope' 'Melanesia' 'Micronesia' 'MiddleAfrica' 'NorthernAfrica'
#  'NorthernAmerica' 'NorthernEurope' 'Oceania' 'Polynesia'
#  'South-easternAsia' 'SouthAmerica' 'SouthernAfrica' 'SouthernAsia'
#  'SouthernEurope' 'WesternAfrica' 'WesternAsia' 'WesternEurope']

# %%
for index, category in enumerate(LE.classes_):
  print(f"{category} -> {index}")
# Out:
# Caribbean -> 0
# CentralAmerica -> 1
# CentralAsia -> 2
# EasternAfrica -> 3
# EasternAsia -> 4
# EasternEurope -> 5
# Melanesia -> 6
# Micronesia -> 7
# MiddleAfrica -> 8
# NorthernAfrica -> 9
# NorthernAmerica -> 10
# NorthernEurope -> 11
# Oceania -> 12
# Polynesia -> 13
# South-easternAsia -> 14
# SouthAmerica -> 15
# SouthernAfrica -> 16
# SouthernAsia -> 17
# SouthernEurope -> 18
# WesternAfrica -> 19
# WesternAsia -> 20
# WesternEurope -> 21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     200 non-null    object
#  1   Region                                                      200 non-null    int64
#  2   Surface area (km2)                                          200 non-null    object
#  3   Population in thousands (2017)                              200 non-null    int64
#  4   Population density (per km2, 2017)                          200 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               200 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           200 non-null    int64
# ...

# %%
df['Region']
# Out:
# 0      17
# 1      18
# 2       9
# 3      13
# 4      18
#        ..
# 224    13
# 225     9
# 226    20
# 227     3
# 228     3
# Name: Region, Length: 200, dtype: int64

# %%
#Create a function which takes df as an input and it eliminates the outliers fromt the df for all the columns

def outlier_remover(df):
  for col in df.columns: #for each and every column in df.columns
    if(df[col].dtype!='object'): #if data type is not object-> that means numerical
      Q1=df[col].quantile(0.25)
      Q3=df[col].quantile(0.75)

      IQR=Q3-Q1

      LB=Q1-1.5*(IQR)
      UB=Q3+1.5*(IQR)
      df=df[(df[col]>=LB)&(df[col]<=UB)]

outlier_remover(df)

# %%
#create a function which takes df as an input and it label encodes all the object columns

def labelencoder(df):
  for col in df.columns:
    if(df[col].dtype=='object'):
      df[col]=LE.fit_transform(df[col])
labelencoder(df)
# Out:
# /tmp/ipython-input-74-1168058200.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=LE.fit_transform(df[col])
# /tmp/ipython-input-74-1168058200.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=LE.fit_transform(df[col])
# /tmp/ipython-input-74-1168058200.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     200 non-null    int64
#  1   Region                                                      200 non-null    int64
#  2   Surface area (km2)                                          200 non-null    int64
#  3   Population in thousands (2017)                              200 non-null    int64
#  4   Population density (per km2, 2017)                          200 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               200 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           200 non-null    int64
#  7   GDP growth rate (annual %, const. 2005 prices)              200 non-null    int64
# ...

# %%
small_df=df.iloc[:,:10] #all rows, cols from 0 to 9
small_df
# Out:
#      country  Region  Surface area (km2)  Population in thousands (2017)  \
# 0          0      17                 161                           35530
# 1          1      18                  95                            2930
# 2          2       9                  71                           41318
# 3          3      13                  55                              56
# 4          4      18                 134                              77
# ..       ...     ...                 ...                             ...
# 224      195      13                  33                              12
# 225      196       9                  85                             553
# 226      197      20                 143                           28250
# 227      198       3                 172                           17094
# 228      199       3                 117                           16530
#
#      Population density (per km2, 2017)  Sex ratio (m per 100 f, 2017)  \
# ...

# %%
small_df.corr()
# Out:
#                                                     country    Region  \
# country                                            1.000000  0.003049
# Region                                             0.003049  1.000000
# Surface area (km2)                                 0.057549  0.084311
# Population in thousands (2017)                     0.071529  0.086013
# Population density (per km2, 2017)                -0.034027  0.044361
# Sex ratio (m per 100 f, 2017)                      0.077907  0.189184
# GDP: Gross domestic product (million current US$) -0.021545  0.181221
# GDP growth rate (annual %, const. 2005 prices)     0.094511 -0.019002
# GDP per capita (current US$)                      -0.057937  0.183641
# Economy: Agriculture (% of GVA)                    0.044062  0.088468
#
#                                                    Surface area (km2)  \
# country                                                      0.057549
# ...

# %%
#heatmap : 2D color coded matrix
fig=plt.subplots(1,1, figsize=(20,10))

plt.subplot(1,1,1)
sns.heatmap(small_df.corr(), annot=True)
plt.show()

# %%
df2=sns.load_dataset('tips')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Find the probability of the day being Sunday from the df2
#prob=fav outcomes/total
#fav=day==sunday
#total=length of day

# %%
favOut=len(df2[df2['day']=='Sun'])
total=len(df2['day'])
print((favOut/total)*100)
# Out:
# 31.147540983606557

# %%
df2[df2['day']=='Sun']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
#Given that time is Dinner, what is the probability of a day being Sunday?

favOut=len(df2[(df2['time']=='Dinner')&(df2['day']=='Sun')])
total=len(df2[df2['time']=='Dinner'])
(favOut/total)*100
# Out:
# 43.18181818181818

# %%
df2[(df2['time']=='Dinner')&(df2['day']=='Sun')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
df2[df2['time']=='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
#Given that time is Dinner, what is the probability of a day being Saturday or Friday?

favOut=len(df2[(df2['time']=='Dinner')&((df2['day']=='Sat') | (df2['day']=='Fri'))])
total=len(df2[df2['time']=='Dinner'])
(favOut/total)*100
# Out:
# 56.25

# %%
df2[df2['day']=='Sat']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
df2[df2['day']=='Fri']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 90        28.97  3.00    Male    Yes  Fri  Dinner     2
# 91        22.49  3.50    Male     No  Fri  Dinner     2
# 92         5.75  1.00  Female    Yes  Fri  Dinner     2
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2
# 97        12.03  1.50    Male    Yes  Fri  Dinner     2
# 98        21.01  3.00    Male    Yes  Fri  Dinner     2
# 99        12.46  1.50    Male     No  Fri  Dinner     2
# 100       11.35  2.50  Female    Yes  Fri  Dinner     2
# 101       15.38  3.00  Female    Yes  Fri  Dinner     2
# 220       12.16  2.20    Male    Yes  Fri   Lunch     2
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2
# 222        8.58  1.92    Male    Yes  Fri   Lunch     1
# 223       15.98  3.00  Female     No  Fri   Lunch     3
# ...
