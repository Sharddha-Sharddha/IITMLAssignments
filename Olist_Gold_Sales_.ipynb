# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharddha-Sharddha/IITMLAssignments/blob/main/Olist_Gold_Sales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/Olist_Gold_Sales_master_1.csv',header=0)

# %%
df.head()
# Out:
#                            order_id  payment_value order_purchase_timestamp  \
# 0  00789ce015e7e5791c7914f32bb4fad4     190.809998                  31:33.0
# 1  00c42b1633c1b2fa4e937bf312466561      55.000000                  52:54.0
# 2  00dc6ad47477b3b62d3c0acbe98a82a4     144.220001                  41:24.0
# 3  00f86b368251d739f1896d41469b2b7a     175.050003                  15:06.0
# 4  00f86b368251d739f1896d41469b2b7a     175.050003                  15:06.0
#
#     customer_city customer_state    product_category_name_english       price  \
# 0  rio de janeiro             RJ                    health_beauty  154.000000
# 1        imbituba             SC                  furniture_decor   39.900002
# 2         caruaru             PE                              art  110.989998
# 3     passo fundo             RS  construction_tools_construction   39.970001
# 4     passo fundo             RS  construction_tools_construction   39.970001
#
#    freight_value payment_type
# ...

# %%
# !pip install pyodbc
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.3/340.3 kB 18.2 MB/s eta 0:00:00
# ...

# %%
import pyodbc

conn = pyodbc.connect('DRIVER={SQL Server};SERVER=YOUR_SERVER;DATABASE=Olist_Project;Trusted_Connection=yes;')

# Use read_sql - it is designed to grab those headers automatically
df = pd.read_sql("SELECT * FROM View_Gold_Sales_Master", conn)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipykernel_3946/3660373063.py in <cell line: 0>()
#       1 import pyodbc
#       2
# ----> 3 conn = pyodbc.connect('DRIVER={SQL Server};SERVER=YOUR_SERVER;DATABASE=Olist_Project;Trusted_Connection=yes;')
#       4
#       5 # Use read_sql - it is designed to grab those headers automatically
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'SQL Server' : file not found (0) (SQLDriverConnect)")
